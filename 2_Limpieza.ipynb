# %% [markdown]
# # Limpieza del DataSet: IMDB 5000 Movie
#
# En este notebook se realiza un proceso de limpieza de datos incluyendo:
#
# 1. Carga del dataset
# 2. Renombrar y ordenar columnas
# 3. Gestión de valores nulos
# 4. Corrección de tipos
# 	1. Corrección de tipos numéricos
# 	2. Normalización de strings
# 	3. Limpieza de columnas con valores múltiples
# 5. Detección y eliminación de duplicados
# 6. Guardar dataset

# %% [markdown]
# ## 1. Carga del DataSet

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("movie_metadata.csv")
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 2. Renombrar y ordenar columnas

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# Las columnas están desordenadas y con nombres que a lo mejor no son aclarativos. Por eso se van a modificar las cabeceras para que sean mas leibles y descriptivas.
#
# Esto facilitará la manipulación de datos más adelante.

# %%
df.columns = [col.replace("_", " ").title() for col in df.columns]

nuevo_orden = [
    # Información básica de la película
    "Movie Title", "Title Year", "Movie Imdb Link", "Language", "Country", "Content Rating",
    # Información cinematográfica
    "Duration", "Color", "Genres", "Aspect Ratio", "Plot Keywords", "Facenumber In Poster",
    # Reparto
    "Director Name", "Actor 1 Name", "Actor 2 Name", "Actor 3 Name",
    # Dinero
    "Budget", "Gross",
    # Calidad
    "Num Voted Users", "Num User For Reviews", "Num Critic For Reviews", "Imdb Score",
    # Facebook
    "Director Facebook Likes", "Actor 1 Facebook Likes", "Actor 2 Facebook Likes",
    "Actor 3 Facebook Likes", "Cast Total Facebook Likes", "Movie Facebook Likes"
]

df = df[nuevo_orden]

# %% [markdown]
# ## 3. Revisión de nulos y tipos

# %%
df.isna().sum()
# Out:
# Movie Title                    0
# Title Year                   108
# Movie Imdb Link                0
# Language                      14
# Country                        5
# Content Rating               303
# Duration                      15
# Color                         19
# Genres                         0
# Aspect Ratio                 329
# Plot Keywords                153
# Facenumber In Poster          13
# Director Name                104
# Actor 1 Name                   7
# Actor 2 Name                  13
# Actor 3 Name                  23
# Budget                       492
# Gross                        884
# Num Voted Users                0
# Num User For Reviews          21
# Num Critic For Reviews        50
# Imdb Score                     0
# Director Facebook Likes      104
# Actor 1 Facebook Likes         7
# Actor 2 Facebook Likes        13
# Actor 3 Facebook Likes        23
# Cast Total Facebook Likes      0
# Movie Facebook Likes           0
# dtype: int64

# %% [markdown]
# Viendo la cantidad de valores nulos de cada columna se pueden dividir en 3 grupos:
# - Columnas sin nulos: Columnas que no contienen nulos y por lo tanto no son importantes a observar en este apartado.
# - Columnas esenciales con nulos: Columnas que al tener nulos hacen que haya que eliminar la fila.
# - Columnas no esenciales con nulos: Columnas en las que los nulos se les puede dar un valor por defecto.
#
# Desglose:
# - Sin nulos: Titulo, URL IMDB, Generos, Votos usuarios IMDB, Puntuacion IMDB, Facebook likes del reparto, Facebook likes pelicula.
# - Esenciales: Año lanzamiento, Duracion, Nombre director, Nombre actor 1.
# - No esenciales: Idiomas, Pais, Clasificacion, Color, Relacion aspecto, Palabras clave trama, Caras en poster, Nombre actor 2, Nombre actor 3, Presupuesto, Recaudacion, Numero reseñas usuarios, Numero reseñas criticos, Facebook likes director, Facebook likes actor 1, Facebook likes actor 2, Facebook likes actor 3.

# %%
# Número de filas actualmente en el dataset
len(df)
# Out:
# 5043

# %%
# ESENCIALES:
esenciales = ["Title Year", "Duration", "Director Name", "Actor 1 Name"]
df = df.dropna(subset=esenciales)

# Número de filas tras eliminar las filas con valores nulos en columnas esenciales
len(df)
# Out:
# 4916

# %% [markdown]
# Se pasa de tener 5043 filas a 4916 tras eliminar todas las filas con nulos en las columnas consideradas esenciales.

# %%
# NO ESENCIALES:
for col in ["Language", "Country", "Content Rating", "Color", "Plot Keywords", 
            "Actor 2 Name", "Actor 3 Name"]:
    df[col] = df[col].fillna("Unknown")
    
for col in ["Facenumber In Poster", "Num User For Reviews", "Num Critic For Reviews", 
            "Director Facebook Likes", "Actor 1 Facebook Likes", 
            "Actor 2 Facebook Likes", "Actor 3 Facebook Likes"]:
    df[col] = df[col].fillna(0)
    
for col in ["Aspect Ratio", "Budget", "Gross"]:
    df[col] = df[col].fillna(df[col].median())

df.isna().sum()
# Out:
# Movie Title                  0
# Title Year                   0
# Movie Imdb Link              0
# Language                     0
# Country                      0
# Content Rating               0
# Duration                     0
# Color                        0
# Genres                       0
# Aspect Ratio                 0
# Plot Keywords                0
# Facenumber In Poster         0
# Director Name                0
# Actor 1 Name                 0
# Actor 2 Name                 0
# Actor 3 Name                 0
# Budget                       0
# Gross                        0
# Num Voted Users              0
# Num User For Reviews         0
# Num Critic For Reviews       0
# Imdb Score                   0
# Director Facebook Likes      0
# Actor 1 Facebook Likes       0
# Actor 2 Facebook Likes       0
# Actor 3 Facebook Likes       0
# Cast Total Facebook Likes    0
# Movie Facebook Likes         0
# dtype: int64

# %% [markdown]
# Se puede comprobar que se han limpiado todos los datos tras rellenar los nulos de las columnas no esenciales con valores por defecto.

# %% [markdown]
# ## 4. Corrección de tipos

# %% [markdown]
# ### 4.1. Corrección de tipos numéricos

# %% [markdown]
# Se va a asegurar que todas las columnas numéricas sean del tipo correcto (`int` o `float`).
# Esto permitirá operaciones matemáticas y estadísticas sin errores.

# %%
col_float = ["Aspect Ratio", "Budget", "Gross", "Imdb Score"]

for col in col_float:
    df[col] = df[col].astype(float)

# %%
col_int = ["Title Year", "Duration", "Facenumber In Poster", "Num Voted Users", "Num User For Reviews", "Num Critic For Reviews", "Director Facebook Likes", 
	"Actor 1 Facebook Likes", "Actor 2 Facebook Likes", "Actor 3 Facebook Likes", "Cast Total Facebook Likes", "Movie Facebook Likes"]

for col in col_int:
    df[col] = df[col].astype(int)

# %% [markdown]
# ### 4.2. Normalización de strings

# %% [markdown]
# Se van a quitar los espacios al inicio y al final de los strings, y esto evita errores de coincidencia en filtros o análisis de categorías.

# %%
col_string = ["Movie Title", "Movie Imdb Link", "Language", "Country", "Content Rating", "Color",
              "Genres", "Plot Keywords", "Director Name", "Actor 1 Name",
              "Actor 2 Name", "Actor 3 Name", ]

for col in col_string:
    df[col] = df[col].astype(str).str.strip()

# %% [markdown]
# ### 4.3. Limpieza de columnas con valores múltiples

# %% [markdown]
# Se van a limpiar los espacios y carácteres especiales (`\n`, `\t` y `"`) en "Genres" y "Plot Keywords" en cada unos de sus valores.
#
# Antes de nada reseteamos el indice para poder recorrer correctamente el df, ya que al haber eliminado filas puede darnos error.

# %%
df = df = df.reset_index(drop=True)

# %%
# Genre
for i in range(len(df)):
    generos = df.loc[i, "Genres"]
    partes = generos.split("|")
    partes_limpias = [re.sub(r'[\n\t"]', '', g.strip()) for g in partes]
    df.loc[i, "Genres"] = "|".join(partes_limpias)

# %%
# Plot Keywords
for i in range(len(df)):    
    kw = df.loc[i, "Plot Keywords"]
    partes = kw.split("|")
    partes_limpias = [re.sub(r'[\n\t"]', '', k.strip()) for k in partes]
    df.loc[i, "Plot Keywords"] = "|".join(partes_limpias)

# %% [markdown]
# ## 5. Detección y eliminación de duplicados

# %% [markdown]
# Se van a identificar y tratar si existen filas duplicadas.
#
# En este caso se considera que ninguna de las columnas nombradas anteriormente actúan como id, ya que se puede repetir su valor en varias filas.
#
# Por lo tanto, se van a buscar filas cuyos campos sean todos iguales (`fila1==fila2`)

# %%
duplicadas = df[df.duplicated(keep="first")]
duplicadas.sort_values(by="Movie Title")
# Out:
#                                     Movie Title  Title Year  \
# 4826                          A Dog's Breakfast        2007
# 4302           A Woman, a Gun and a Noodle Shop        2009
# 2508                                   Bad Moms        2016
# 2738                               Big Fat Liar        2002
# 4821                                 Cat People        1982
# 3380                                      Crash        2004
# 4653                                 Crossroads        2002
# 2717                         Dangerous Liaisons        1988
# 2245                         Death at a Funeral        2007
# 383                              Fantastic Four        2015
# 3276                                  Footloose        1984
# 2419                                   Forsaken        2015
# 1419                                  From Hell        2001
# 201                         Godzilla Resurgence        2016
# 2563                                  Halloween        1978
# 4084                               Halloween II        2009
# 4182                                     Hamlet        1996
# 579                                    Hercules        2014
# 2440                                       Hero        2002
# 4461               History of the World: Part I        1981
# 2514                                Left Behind        2014
# 3826                            My Soul to Take        2010
# 4827                   Night of the Living Dead        1968
# 3648                                          O        2001
# 297                                         Pan        2015
# 3052                                     Snatch        2000
# 4210                           Stealing Harvard        2002
# 2907                                  The Alamo        2004
# 779                                The Avengers        2012
# 4806                                The Calling        2014
# 3408                                  The Claim        2000
# 389                    The Fast and the Furious        2001
# 4128                      The French Connection        1971
# 4453                             The Full Monty        1997
# 2480                            The Illusionist        2006
# 136                        The Legend of Tarzan        2016
# 4761                            The Love Letter        1998
# 2712                             The Possession        2012
# 185   The Twilight Saga: Breaking Dawn - Part 2        2012
# 643                                Total Recall        1990
# 4518                                     Trance        2013
# 1194                                   Unbroken        2014
# 1278                        Victor Frankenstein        2015
# 2125                                Wicker Park        2004
#
#                                         Movie Imdb Link  Language  Country  \
# 4826  http://www.imdb.com/title/tt0796314/?ref_=fn_t...   English   Canada
# 4302  http://www.imdb.com/title/tt1428556/?ref_=fn_t...  Mandarin    China
# 2508  http://www.imdb.com/title/tt4651520/?ref_=fn_t...   English      USA
# 2738  http://www.imdb.com/title/tt0265298/?ref_=fn_t...   English      USA
# 4821  http://www.imdb.com/title/tt0083722/?ref_=fn_t...   English      USA
# 3380  http://www.imdb.com/title/tt0375679/?ref_=fn_t...   English  Germany
# 4653  http://www.imdb.com/title/tt0275022/?ref_=fn_t...   English      USA
# 2717  http://www.imdb.com/title/tt0094947/?ref_=fn_t...   English      USA
# 2245  http://www.imdb.com/title/tt0795368/?ref_=fn_t...   English      USA
# 383   http://www.imdb.com/title/tt1502712/?ref_=fn_t...   English      USA
# 3276  http://www.imdb.com/title/tt0087277/?ref_=fn_t...   English      USA
# 2419  http://www.imdb.com/title/tt2271563/?ref_=fn_t...   English   Canada
# 1419  http://www.imdb.com/title/tt0120681/?ref_=fn_t...   English      USA
# 201   http://www.imdb.com/title/tt4262980/?ref_=fn_t...  Japanese    Japan
# 2563  http://www.imdb.com/title/tt0077651/?ref_=fn_t...   English      USA
# 4084  http://www.imdb.com/title/tt1311067/?ref_=fn_t...   English      USA
# 4182  http://www.imdb.com/title/tt0116477/?ref_=fn_t...   English       UK
# 579   http://www.imdb.com/title/tt1267297/?ref_=fn_t...   English      USA
# 2440  http://www.imdb.com/title/tt0299977/?ref_=fn_t...  Mandarin    China
# 4461  http://www.imdb.com/title/tt0082517/?ref_=fn_t...   English      USA
# 2514  http://www.imdb.com/title/tt2467046/?ref_=fn_t...   English      USA
# 3826  http://www.imdb.com/title/tt0872230/?ref_=fn_t...   English      USA
# 4827  http://www.imdb.com/title/tt0063350/?ref_=fn_t...   English      USA
# 3648  http://www.imdb.com/title/tt0184791/?ref_=fn_t...   English      USA
# 297   http://www.imdb.com/title/tt3332064/?ref_=fn_t...   English      USA
# 3052  http://www.imdb.com/title/tt0208092/?ref_=fn_t...   English       UK
# 4210  http://www.imdb.com/title/tt0265808/?ref_=fn_t...   English      USA
# 2907  http://www.imdb.com/title/tt0318974/?ref_=fn_t...   English      USA
# 779   http://www.imdb.com/title/tt0848228/?ref_=fn_t...   English      USA
# 4806  http://www.imdb.com/title/tt1666335/?ref_=fn_t...   English      USA
# 3408  http://www.imdb.com/title/tt0218378/?ref_=fn_t...   English       UK
# 389   http://www.imdb.com/title/tt0232500/?ref_=fn_t...   English      USA
# 4128  http://www.imdb.com/title/tt0067116/?ref_=fn_t...   English      USA
# 4453  http://www.imdb.com/title/tt0119164/?ref_=fn_t...   English       UK
# 2480  http://www.imdb.com/title/tt0443543/?ref_=fn_t...   English      USA
# 136   http://www.imdb.com/title/tt0918940/?ref_=fn_t...   English      USA
# 4761  http://www.imdb.com/title/tt0140340/?ref_=fn_t...   English      USA
# 2712  http://www.imdb.com/title/tt0431021/?ref_=fn_t...   English      USA
# 185   http://www.imdb.com/title/tt1673434/?ref_=fn_t...   English      USA
# 643   http://www.imdb.com/title/tt0100802/?ref_=fn_t...   English      USA
# 4518  http://www.imdb.com/title/tt1924429/?ref_=fn_t...   English       UK
# 1194  http://www.imdb.com/title/tt1809398/?ref_=fn_t...   English      USA
# 1278  http://www.imdb.com/title/tt1976009/?ref_=fn_t...   English      USA
# 2125  http://www.imdb.com/title/tt0324554/?ref_=fn_t...   English      USA
#
#      Content Rating  Duration            Color  \
# 4826        Unknown        88            Color
# 4302              R        95            Color
# 2508              R       100            Color
# 2738             PG        88            Color
# 4821              R        93            Color
# 3380              R       115            Color
# 4653          PG-13        93            Color
# 2717              R       119            Color
# 2245              R        87            Color
# 383           PG-13       100            Color
# 3276             PG       107            Color
# 2419              R        90            Color
# 1419              R       122            Color
# 201         Unknown       120            Color
# 2563              R       101            Color
# 4084              R       119            Color
# 4182          PG-13       150            Color
# 579           PG-13       101            Color
# 2440          PG-13        80  Black and White
# 4461              R        92            Color
# 2514          PG-13       110            Color
# 3826              R       107            Color
# 4827        Unrated        96  Black and White
# 3648              R        95            Color
# 297              PG       111            Color
# 3052              R       104            Color
# 4210          PG-13        85            Color
# 2907          PG-13       137            Color
# 779           PG-13       173            Color
# 4806              R       108            Color
# 3408              R       115            Color
# 389           PG-13       106            Color
# 4128              R       104            Color
# 4453              R        91            Color
# 2480          PG-13       110            Color
# 136           PG-13       110            Color
# 4761        Unrated        99            Color
# 2712          PG-13        92            Color
# 185           PG-13       115            Color
# 643               R       113            Color
# 4518              R       101            Color
# 1194          PG-13       137            Color
# 1278          PG-13       110            Color
# 2125          PG-13       114            Color
#
#                                      Genres  Aspect Ratio  ...  \
# 4826                                 Comedy          1.78  ...
# 4302                           Comedy|Drama          2.35  ...
# 2508                                 Comedy          2.35  ...
# 2738                Adventure|Comedy|Family          1.85  ...
# 4821                Fantasy|Horror|Thriller          1.85  ...
# 3380                   Crime|Drama|Thriller          2.35  ...
# 4653                           Comedy|Drama          1.85  ...
# 2717                          Drama|Romance          1.85  ...
# 2245                                 Comedy          1.85  ...
# 383                 Action|Adventure|Sci-Fi          2.35  ...
# 3276                    Drama|Music|Romance          1.85  ...
# 2419                          Drama|Western          2.35  ...
# 1419                Horror|Mystery|Thriller          2.35  ...
# 201    Action|Adventure|Drama|Horror|Sci-Fi          2.35  ...
# 2563                        Horror|Thriller          2.35  ...
# 4084                                 Horror          1.85  ...
# 4182                                  Drama          2.20  ...
# 579                        Action|Adventure          2.35  ...
# 2440               Action|Adventure|History          2.35  ...
# 4461                                 Comedy          2.35  ...
# 2514  Action|Drama|Fantasy|Mystery|Thriller          2.35  ...
# 3826                Horror|Mystery|Thriller          2.35  ...
# 4827                   Drama|Horror|Mystery          1.85  ...
# 3648                 Drama|Romance|Thriller          1.85  ...
# 297                Adventure|Family|Fantasy          2.35  ...
# 3052                           Comedy|Crime          1.85  ...
# 4210                           Comedy|Crime          1.85  ...
# 2907              Drama|History|War|Western          2.35  ...
# 779                 Action|Adventure|Sci-Fi          1.85  ...
# 4806                               Thriller          2.35  ...
# 3408                  Drama|Romance|Western          2.35  ...
# 389                   Action|Crime|Thriller          2.35  ...
# 4128            Action|Crime|Drama|Thriller          1.85  ...
# 4453                     Comedy|Drama|Music          1.85  ...
# 2480         Drama|Mystery|Romance|Thriller          1.85  ...
# 136          Action|Adventure|Drama|Romance          2.35  ...
# 4761                        Fantasy|Romance          1.33  ...
# 2712                        Horror|Thriller          2.35  ...
# 185         Adventure|Drama|Fantasy|Romance          2.35  ...
# 643                           Action|Sci-Fi          1.85  ...
# 4518           Crime|Drama|Mystery|Thriller          2.35  ...
# 1194              Biography|Drama|Sport|War          2.35  ...
# 1278           Drama|Horror|Sci-Fi|Thriller          2.35  ...
# 2125         Drama|Mystery|Romance|Thriller          2.35  ...
#
#      Num Voted Users  Num User For Reviews Num Critic For Reviews Imdb Score  \
# 4826            3262                    46                      8        7.0
# 4302            2410                    20                    101        5.7
# 2508            4654                    46                     81        6.7
# 2738           29008                    99                     69        5.4
# 4821           14193                   106                    130        6.1
# 3380          361169                  1624                    287        7.9
# 4653           34219                   578                    111        3.3
# 2717           52846                   143                     51        7.7
# 2245           89547                   199                    168        7.4
# 383           110486                   695                    369        4.3
# 3276           51459                   113                     60        6.5
# 2419            4693                    49                     45        6.3
# 1419          124765                   541                    208        6.8
# 201              374                    13                      1        8.2
# 2563          157857                  1191                    318        7.9
# 4084           36372                   491                    220        4.9
# 4182           30618                   224                     85        7.8
# 579           115687                   269                    245        6.0
# 2440          149414                   841                    283        7.9
# 4461           36559                   131                     48        6.9
# 2514           24854                   374                    169        3.1
# 3826           16411                   136                    160        4.8
# 4827           87978                   580                    284        8.0
# 3648           17333                   153                     92        6.2
# 297            39956                   186                    256        5.8
# 3052          600996                   726                    151        8.3
# 4210           11211                    92                     52        5.1
# 2907           16832                   267                    106        6.0
# 779           995415                  1722                    703        8.1
# 4806            6025                    28                     48        5.8
# 3408            5254                    92                     71        6.5
# 389           272223                   988                    187        6.7
# 4128           82476                   280                    138        7.8
# 4453           82232                   174                    122        7.2
# 2480          295375                   645                    236        7.6
# 136            42372                   239                    248        6.6
# 4761            1465                    56                      0        7.4
# 2712           47169                   162                    264        5.9
# 185           185394                   329                    322        5.5
# 643           240241                   391                    196        7.5
# 4518           92640                   212                    393        7.0
# 1194          103589                   351                    322        7.2
# 1278           28618                    91                    159        6.0
# 2125           44979                   298                     98        7.0
#
#      Director Facebook Likes Actor 1 Facebook Likes  Actor 2 Facebook Likes  \
# 4826                     686                    847                     686
# 4302                     611                      9                       4
# 2508                      24                  15000                    1000
# 2738                     189                    934                     927
# 4821                     261                    783                     782
# 3380                     549                   3000                     912
# 4653                      33                   1000                     188
# 2717                     350                  18000                   17000
# 2245                       0                  22000                     557
# 383                      128                    596                     360
# 3276                      71                    967                     455
# 2419                      78                   2000                    1000
# 1419                     117                  40000                    1000
# 201                       28                    544                     106
# 2563                       0                   2000                     742
# 4084                       0                    908                     764
# 4182                       0                    597                     591
# 579                      420                  12000                    3000
# 2440                     611                   5000                     643
# 4461                       0                   1000                     898
# 2514                     179                  12000                    1000
# 3826                       0                    798                     374
# 4827                       0                    125                     108
# 3648                     596                   1000                     835
# 297                      456                  20000                     548
# 3052                       0                  26000                   11000
# 4210                      54                    985                     637
# 2907                     102                   2000                     973
# 779                        0                  26000                   21000
# 4806                      14                   2000                    1000
# 3408                     187                  14000                     900
# 389                      357                  23000                   14000
# 4128                     607                    813                     165
# 4453                      11                   1000                     891
# 2480                     168                   3000                     979
# 136                      282                  11000                   10000
# 4761                      45                   1000                     393
# 2712                      30                    941                     459
# 185                      386                  21000                   17000
# 643                      719                    605                     308
# 4518                       0                   3000                    1000
# 1194                   11000                    769                     698
# 1278                     118                  11000                    1000
# 2125                     118                    489                      93
#
#       Actor 3 Facebook Likes  Cast Total Facebook Likes  Movie Facebook Likes
# 4826                     405                       2364                   377
# 4302                       3                         18                   784
# 2508                     851                      18786                 18000
# 2738                     799                       3707                   896
# 4821                     697                       3700                     0
# 3380                     911                       5732                 18000
# 4653                     135                       1531                     0
# 2717                     418                      35501                     0
# 2245                     548                      24324                     0
# 383                       78                       1261                 41000
# 3276                     304                       1962                     0
# 2419                     720                       4142                     0
# 1419                     140                      41636                     0
# 201                       12                        699                     0
# 2563                     598                       4400                 12000
# 4084                     593                       3226                  3000
# 4182                     401                       1645                     0
# 579                      467                      16235                 21000
# 2440                     576                       6229                     0
# 4461                     842                       3931                     0
# 2514                     734                      15044                 31000
# 3826                     255                       2537                     0
# 4827                      56                        403                     0
# 3648                     697                       3300                     0
# 297                      394                      21393                 24000
# 3052                    1000                      39175                 27000
# 4210                     455                       3065                   215
# 2907                     877                       5780                   701
# 779                    19000                      87697                123000
# 4806                     826                       4385                     0
# 3408                     887                      17104                   141
# 389                     4000                      45327                 14000
# 4128                     109                       1196                     0
# 4453                     121                       2323                     0
# 2480                      96                       4210                 15000
# 136                      103                      21175                 29000
# 4761                     224                       2166                   515
# 2712                     309                       2348                 17000
# 185                    12000                      59177                 65000
# 643                      217                       1441                     0
# 4518                     888                       5056                 23000
# 1194                     465                       2938                 35000
# 1278                     287                      12876                 11000
# 2125                      40                        679                     0
#
# [44 rows x 28 columns]

# %% [markdown]
# 44 películas duplicadas que hay que eliminar.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 6. Guardar DataSet

# %%
df.to_csv("imdb_5000_movies_limpio.csv", index=False)
