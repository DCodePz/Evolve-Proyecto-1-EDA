# %% [markdown]
# # Limpieza del DataSet: IMDB 5000 Movie
#
# En este notebook se realiza un proceso de limpieza de datos incluyendo:
#
# 1. Carga del dataset
# 2. Renombrar y ordenar columnas
# 3. Gestión de valores nulos
# 4. Corrección de tipos
# 	1. Corrección de tipos numéricos
# 	2. Normalización de strings
# 	3. Limpieza de columnas con valores múltiples
# 5. Detección y eliminación de duplicados
# 6. Comprobar datos y abordar incoherencias
# 7. Guardar dataset

# %% [markdown]
# ## 1. Carga del dataset

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("../data/movie_metadata.csv")
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 2. Renombrar y ordenar columnas

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# Las columnas están desordenadas y con nombres que a lo mejor no son aclarativos. Por eso se van a modificar las cabeceras para que sean mas leibles y descriptivas.
#
# Esto facilitará la manipulación de datos más adelante.

# %%
df.columns = [col.replace("_", " ").title() for col in df.columns]

nuevo_orden = [
    # Información básica de la película
    "Movie Title", "Title Year", "Movie Imdb Link", "Language", "Country", "Content Rating",
    # Información cinematográfica
    "Duration", "Color", "Genres", "Aspect Ratio", "Plot Keywords", "Facenumber In Poster",
    # Reparto
    "Director Name", "Actor 1 Name", "Actor 2 Name", "Actor 3 Name",
    # Dinero
    "Budget", "Gross",
    # Calidad
    "Num Voted Users", "Num User For Reviews", "Num Critic For Reviews", "Imdb Score",
    # Facebook
    "Director Facebook Likes", "Actor 1 Facebook Likes", "Actor 2 Facebook Likes",
    "Actor 3 Facebook Likes", "Cast Total Facebook Likes", "Movie Facebook Likes"
]

df = df[nuevo_orden]

# %% [markdown]
# ## 3. Revisión de nulos y tipos

# %%
df.isna().sum()
# Out:
# Movie Title                    0
# Title Year                   108
# Movie Imdb Link                0
# Language                      14
# Country                        5
# Content Rating               303
# Duration                      15
# Color                         19
# Genres                         0
# Aspect Ratio                 329
# Plot Keywords                153
# Facenumber In Poster          13
# Director Name                104
# Actor 1 Name                   7
# Actor 2 Name                  13
# Actor 3 Name                  23
# Budget                       492
# Gross                        884
# Num Voted Users                0
# Num User For Reviews          21
# Num Critic For Reviews        50
# Imdb Score                     0
# Director Facebook Likes      104
# Actor 1 Facebook Likes         7
# Actor 2 Facebook Likes        13
# Actor 3 Facebook Likes        23
# Cast Total Facebook Likes      0
# Movie Facebook Likes           0
# dtype: int64

# %% [markdown]
# Siguiendo lo observado en la exploración se procede a tratar los nulos.

# %%
# Número de filas actualmente en el dataset
len(df)
# Out:
# 5043

# %%
# Remplazar por 0:
por0 = ["Director Facebook Likes", "Actor 1 Facebook Likes", "Actor 2 Facebook Likes", 
        "Actor 3 Facebook Likes", "Facenumber In Poster"]
for col in por0:
    df[col] = df[col].fillna(0)

# %%
# Remplazar por la mediana:
porMediana = ["Duration", "Budget", "Num Critic For Reviews", "Num User For Reviews", "Gross",
              "Title Year"]
for col in porMediana:
    df[col] = df[col].fillna(df[col].median())

# %%
# Remplazar por la moda:
porModa = ["Color", "Language", "Country", "Aspect Ratio"]
for col in porModa:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# Remplazar por la "Unkown":
porUnkown = ["Content Rating", "Actor 1 Name", "Actor 2 Name", "Actor 3 Name", "Director Name",
             "Plot Keywords", "Language"]
for col in porUnkown:
    df[col] = df[col].fillna("Unknown")

# %%
df.isna().sum()
# Out:
# Movie Title                  0
# Title Year                   0
# Movie Imdb Link              0
# Language                     0
# Country                      0
# Content Rating               0
# Duration                     0
# Color                        0
# Genres                       0
# Aspect Ratio                 0
# Plot Keywords                0
# Facenumber In Poster         0
# Director Name                0
# Actor 1 Name                 0
# Actor 2 Name                 0
# Actor 3 Name                 0
# Budget                       0
# Gross                        0
# Num Voted Users              0
# Num User For Reviews         0
# Num Critic For Reviews       0
# Imdb Score                   0
# Director Facebook Likes      0
# Actor 1 Facebook Likes       0
# Actor 2 Facebook Likes       0
# Actor 3 Facebook Likes       0
# Cast Total Facebook Likes    0
# Movie Facebook Likes         0
# dtype: int64

# %% [markdown]
# Se puede comprobar que se han limpiado todos los datos tras remplazar los nulos.

# %% [markdown]
# ## 4. Corrección de tipos

# %% [markdown]
# ### 4.1. Corrección de tipos numéricos

# %% [markdown]
# Se va a asegurar que todas las columnas numéricas sean del tipo correcto (`int` o `float`).
# Esto permitirá operaciones matemáticas y estadísticas sin errores.

# %%
col_float = ["Aspect Ratio", "Budget", "Gross", "Imdb Score"]

for col in col_float:
    df[col] = df[col].astype(float)

# %%
col_int = ["Title Year", "Duration", "Facenumber In Poster", "Num Voted Users", "Num User For Reviews", "Num Critic For Reviews", "Director Facebook Likes", 
	"Actor 1 Facebook Likes", "Actor 2 Facebook Likes", "Actor 3 Facebook Likes", "Cast Total Facebook Likes", "Movie Facebook Likes"]

for col in col_int:
    df[col] = df[col].astype(int)

# %% [markdown]
# ### 4.2. Normalización de strings

# %% [markdown]
# Se van a quitar los espacios al inicio y al final de los strings, y esto evita errores de coincidencia en filtros o análisis de categorías.

# %%
col_string = ["Movie Title", "Movie Imdb Link", "Language", "Country", "Content Rating", "Color",
              "Genres", "Plot Keywords", "Director Name", "Actor 1 Name",
              "Actor 2 Name", "Actor 3 Name", ]

for col in col_string:
    df[col] = df[col].astype(str).str.strip()

# %% [markdown]
# ### 4.3. Limpieza de columnas con valores múltiples

# %% [markdown]
# Se van a limpiar los espacios y carácteres especiales (`\n`, `\t` y `"`) en "Genres" y "Plot Keywords" en cada unos de sus valores.
#
# Antes de nada reseteamos el indice para poder recorrer correctamente el df, ya que al haber eliminado filas puede darnos error.

# %%
df = df = df.reset_index(drop=True)

# %%
# Genre
for i in range(len(df)):
    generos = df.loc[i, "Genres"]
    partes = generos.split("|")
    partes_limpias = [re.sub(r'[\n\t"]', '', g.strip()) for g in partes]
    df.loc[i, "Genres"] = "|".join(partes_limpias)

# %%
# Plot Keywords
for i in range(len(df)):    
    kw = df.loc[i, "Plot Keywords"]
    partes = kw.split("|")
    partes_limpias = [re.sub(r'[\n\t"]', '', k.strip()) for k in partes]
    df.loc[i, "Plot Keywords"] = "|".join(partes_limpias)

# %% [markdown]
# ## 5. Detección y eliminación de duplicados

# %% [markdown]
# Se van a identificar y tratar si existen filas duplicadas.
#
# En este caso se considera que ninguna de las columnas nombradas anteriormente actúan como id, ya que se puede repetir su valor en varias filas.
#
# Por lo tanto, se van a buscar filas cuyos campos sean todos iguales (`fila1==fila2`)

# %%
duplicadas = df[df.duplicated(keep="first")]
duplicadas.sort_values(by="Movie Title")
# Out:
#                                     Movie Title  Title Year  \
# 4950                          A Dog's Breakfast        2007
# 4408           A Woman, a Gun and a Noodle Shop        2009
# 2562                                   Bad Moms        2016
# 2798                               Big Fat Liar        2002
# 4942                                 Cat People        1982
# 3452                                      Crash        2004
# 4769                                 Crossroads        2002
# 2777                         Dangerous Liaisons        1988
# 2292                         Death at a Funeral        2007
# 389                              Fantastic Four        2015
# 3345                                  Footloose        1984
# 2472                                   Forsaken        2015
# 1449                                  From Hell        2001
# 204                         Godzilla Resurgence        2016
# 2619                                  Halloween        1978
# 4182                               Halloween II        2009
# 4282                                     Hamlet        1996
# 590                                    Hercules        2014
# 2493                                       Hero        2002
# 4573               History of the World: Part I        1981
# 2568                                Left Behind        2014
# 3915                            My Soul to Take        2010
# 4951                   Night of the Living Dead        1968
# 3729                                          O        2001
# 303                                         Pan        2015
# 3900                               Saving Grace        2005
# 3117                                     Snatch        2000
# 4313                           Stealing Harvard        2002
# 2971                                  The Alamo        2004
# 794                                The Avengers        2012
# 4927                                The Calling        2014
# 3480                                  The Claim        2000
# 395                    The Fast and the Furious        2001
# 4226                      The French Connection        1971
# 4565                             The Full Monty        1997
# 2533                            The Illusionist        2006
# 137                        The Legend of Tarzan        2016
# 4882                            The Love Letter        1998
# 2771                             The Possession        2012
# 187   The Twilight Saga: Breaking Dawn - Part 2        2012
# 656                                Total Recall        1990
# 4631                                     Trance        2013
# 1220                                   Unbroken        2014
# 1305                        Victor Frankenstein        2015
# 2169                                Wicker Park        2004
#
#                                         Movie Imdb Link  Language  Country  \
# 4950  http://www.imdb.com/title/tt0796314/?ref_=fn_t...   English   Canada
# 4408  http://www.imdb.com/title/tt1428556/?ref_=fn_t...  Mandarin    China
# 2562  http://www.imdb.com/title/tt4651520/?ref_=fn_t...   English      USA
# 2798  http://www.imdb.com/title/tt0265298/?ref_=fn_t...   English      USA
# 4942  http://www.imdb.com/title/tt0083722/?ref_=fn_t...   English      USA
# 3452  http://www.imdb.com/title/tt0375679/?ref_=fn_t...   English  Germany
# 4769  http://www.imdb.com/title/tt0275022/?ref_=fn_t...   English      USA
# 2777  http://www.imdb.com/title/tt0094947/?ref_=fn_t...   English      USA
# 2292  http://www.imdb.com/title/tt0795368/?ref_=fn_t...   English      USA
# 389   http://www.imdb.com/title/tt1502712/?ref_=fn_t...   English      USA
# 3345  http://www.imdb.com/title/tt0087277/?ref_=fn_t...   English      USA
# 2472  http://www.imdb.com/title/tt2271563/?ref_=fn_t...   English   Canada
# 1449  http://www.imdb.com/title/tt0120681/?ref_=fn_t...   English      USA
# 204   http://www.imdb.com/title/tt4262980/?ref_=fn_t...  Japanese    Japan
# 2619  http://www.imdb.com/title/tt0077651/?ref_=fn_t...   English      USA
# 4182  http://www.imdb.com/title/tt1311067/?ref_=fn_t...   English      USA
# 4282  http://www.imdb.com/title/tt0116477/?ref_=fn_t...   English       UK
# 590   http://www.imdb.com/title/tt1267297/?ref_=fn_t...   English      USA
# 2493  http://www.imdb.com/title/tt0299977/?ref_=fn_t...  Mandarin    China
# 4573  http://www.imdb.com/title/tt0082517/?ref_=fn_t...   English      USA
# 2568  http://www.imdb.com/title/tt2467046/?ref_=fn_t...   English      USA
# 3915  http://www.imdb.com/title/tt0872230/?ref_=fn_t...   English      USA
# 4951  http://www.imdb.com/title/tt0063350/?ref_=fn_t...   English      USA
# 3729  http://www.imdb.com/title/tt0184791/?ref_=fn_t...   English      USA
# 303   http://www.imdb.com/title/tt3332064/?ref_=fn_t...   English      USA
# 3900  http://www.imdb.com/title/tt0830900/?ref_=fn_t...   English      USA
# 3117  http://www.imdb.com/title/tt0208092/?ref_=fn_t...   English       UK
# 4313  http://www.imdb.com/title/tt0265808/?ref_=fn_t...   English      USA
# 2971  http://www.imdb.com/title/tt0318974/?ref_=fn_t...   English      USA
# 794   http://www.imdb.com/title/tt0848228/?ref_=fn_t...   English      USA
# 4927  http://www.imdb.com/title/tt1666335/?ref_=fn_t...   English      USA
# 3480  http://www.imdb.com/title/tt0218378/?ref_=fn_t...   English       UK
# 395   http://www.imdb.com/title/tt0232500/?ref_=fn_t...   English      USA
# 4226  http://www.imdb.com/title/tt0067116/?ref_=fn_t...   English      USA
# 4565  http://www.imdb.com/title/tt0119164/?ref_=fn_t...   English       UK
# 2533  http://www.imdb.com/title/tt0443543/?ref_=fn_t...   English      USA
# 137   http://www.imdb.com/title/tt0918940/?ref_=fn_t...   English      USA
# 4882  http://www.imdb.com/title/tt0140340/?ref_=fn_t...   English      USA
# 2771  http://www.imdb.com/title/tt0431021/?ref_=fn_t...   English      USA
# 187   http://www.imdb.com/title/tt1673434/?ref_=fn_t...   English      USA
# 656   http://www.imdb.com/title/tt0100802/?ref_=fn_t...   English      USA
# 4631  http://www.imdb.com/title/tt1924429/?ref_=fn_t...   English       UK
# 1220  http://www.imdb.com/title/tt1809398/?ref_=fn_t...   English      USA
# 1305  http://www.imdb.com/title/tt1976009/?ref_=fn_t...   English      USA
# 2169  http://www.imdb.com/title/tt0324554/?ref_=fn_t...   English      USA
#
#      Content Rating  Duration            Color  \
# 4950        Unknown        88            Color
# 4408              R        95            Color
# 2562              R       100            Color
# 2798             PG        88            Color
# 4942              R        93            Color
# 3452              R       115            Color
# 4769          PG-13        93            Color
# 2777              R       119            Color
# 2292              R        87            Color
# 389           PG-13       100            Color
# 3345             PG       107            Color
# 2472              R        90            Color
# 1449              R       122            Color
# 204         Unknown       120            Color
# 2619              R       101            Color
# 4182              R       119            Color
# 4282          PG-13       150            Color
# 590           PG-13       101            Color
# 2493          PG-13        80  Black and White
# 4573              R        92            Color
# 2568          PG-13       110            Color
# 3915              R       107            Color
# 4951        Unrated        96  Black and White
# 3729              R        95            Color
# 303              PG       111            Color
# 3900          TV-MA        60            Color
# 3117              R       104            Color
# 4313          PG-13        85            Color
# 2971          PG-13       137            Color
# 794           PG-13       173            Color
# 4927              R       108            Color
# 3480              R       115            Color
# 395           PG-13       106            Color
# 4226              R       104            Color
# 4565              R        91            Color
# 2533          PG-13       110            Color
# 137           PG-13       110            Color
# 4882        Unrated        99            Color
# 2771          PG-13        92            Color
# 187           PG-13       115            Color
# 656               R       113            Color
# 4631              R       101            Color
# 1220          PG-13       137            Color
# 1305          PG-13       110            Color
# 2169          PG-13       114            Color
#
#                                      Genres  Aspect Ratio  ...  \
# 4950                                 Comedy          1.78  ...
# 4408                           Comedy|Drama          2.35  ...
# 2562                                 Comedy          2.35  ...
# 2798                Adventure|Comedy|Family          1.85  ...
# 4942                Fantasy|Horror|Thriller          1.85  ...
# 3452                   Crime|Drama|Thriller          2.35  ...
# 4769                           Comedy|Drama          1.85  ...
# 2777                          Drama|Romance          1.85  ...
# 2292                                 Comedy          1.85  ...
# 389                 Action|Adventure|Sci-Fi          2.35  ...
# 3345                    Drama|Music|Romance          1.85  ...
# 2472                          Drama|Western          2.35  ...
# 1449                Horror|Mystery|Thriller          2.35  ...
# 204    Action|Adventure|Drama|Horror|Sci-Fi          2.35  ...
# 2619                        Horror|Thriller          2.35  ...
# 4182                                 Horror          1.85  ...
# 4282                                  Drama          2.20  ...
# 590                        Action|Adventure          2.35  ...
# 2493               Action|Adventure|History          2.35  ...
# 4573                                 Comedy          2.35  ...
# 2568  Action|Drama|Fantasy|Mystery|Thriller          2.35  ...
# 3915                Horror|Mystery|Thriller          2.35  ...
# 4951                   Drama|Horror|Mystery          1.85  ...
# 3729                 Drama|Romance|Thriller          1.85  ...
# 303                Adventure|Family|Fantasy          2.35  ...
# 3900                          Drama|Fantasy          1.78  ...
# 3117                           Comedy|Crime          1.85  ...
# 4313                           Comedy|Crime          1.85  ...
# 2971              Drama|History|War|Western          2.35  ...
# 794                 Action|Adventure|Sci-Fi          1.85  ...
# 4927                               Thriller          2.35  ...
# 3480                  Drama|Romance|Western          2.35  ...
# 395                   Action|Crime|Thriller          2.35  ...
# 4226            Action|Crime|Drama|Thriller          1.85  ...
# 4565                     Comedy|Drama|Music          1.85  ...
# 2533         Drama|Mystery|Romance|Thriller          1.85  ...
# 137          Action|Adventure|Drama|Romance          2.35  ...
# 4882                        Fantasy|Romance          1.33  ...
# 2771                        Horror|Thriller          2.35  ...
# 187         Adventure|Drama|Fantasy|Romance          2.35  ...
# 656                           Action|Sci-Fi          1.85  ...
# 4631           Crime|Drama|Mystery|Thriller          2.35  ...
# 1220              Biography|Drama|Sport|War          2.35  ...
# 1305           Drama|Horror|Sci-Fi|Thriller          2.35  ...
# 2169         Drama|Mystery|Romance|Thriller          2.35  ...
#
#      Num Voted Users  Num User For Reviews Num Critic For Reviews Imdb Score  \
# 4950            3262                    46                      8        7.0
# 4408            2410                    20                    101        5.7
# 2562            4654                    46                     81        6.7
# 2798           29008                    99                     69        5.4
# 4942           14193                   106                    130        6.1
# 3452          361169                  1624                    287        7.9
# 4769           34219                   578                    111        3.3
# 2777           52846                   143                     51        7.7
# 2292           89547                   199                    168        7.4
# 389           110486                   695                    369        4.3
# 3345           51459                   113                     60        6.5
# 2472            4693                    49                     45        6.3
# 1449          124765                   541                    208        6.8
# 204              374                    13                      1        8.2
# 2619          157857                  1191                    318        7.9
# 4182           36372                   491                    220        4.9
# 4282           30618                   224                     85        7.8
# 590           115687                   269                    245        6.0
# 2493          149414                   841                    283        7.9
# 4573           36559                   131                     48        6.9
# 2568           24854                   374                    169        3.1
# 3915           16411                   136                    160        4.8
# 4951           87978                   580                    284        8.0
# 3729           17333                   153                     92        6.2
# 303            39956                   186                    256        5.8
# 3900            3852                    47                      9        7.5
# 3117          600996                   726                    151        8.3
# 4313           11211                    92                     52        5.1
# 2971           16832                   267                    106        6.0
# 794           995415                  1722                    703        8.1
# 4927            6025                    28                     48        5.8
# 3480            5254                    92                     71        6.5
# 395           272223                   988                    187        6.7
# 4226           82476                   280                    138        7.8
# 4565           82232                   174                    122        7.2
# 2533          295375                   645                    236        7.6
# 137            42372                   239                    248        6.6
# 4882            1465                    56                    110        7.4
# 2771           47169                   162                    264        5.9
# 187           185394                   329                    322        5.5
# 656           240241                   391                    196        7.5
# 4631           92640                   212                    393        7.0
# 1220          103589                   351                    322        7.2
# 1305           28618                    91                    159        6.0
# 2169           44979                   298                     98        7.0
#
#      Director Facebook Likes Actor 1 Facebook Likes  Actor 2 Facebook Likes  \
# 4950                     686                    847                     686
# 4408                     611                      9                       4
# 2562                      24                  15000                    1000
# 2798                     189                    934                     927
# 4942                     261                    783                     782
# 3452                     549                   3000                     912
# 4769                      33                   1000                     188
# 2777                     350                  18000                   17000
# 2292                       0                  22000                     557
# 389                      128                    596                     360
# 3345                      71                    967                     455
# 2472                      78                   2000                    1000
# 1449                     117                  40000                    1000
# 204                       28                    544                     106
# 2619                       0                   2000                     742
# 4182                       0                    908                     764
# 4282                       0                    597                     591
# 590                      420                  12000                    3000
# 2493                     611                   5000                     643
# 4573                       0                   1000                     898
# 2568                     179                  12000                    1000
# 3915                       0                    798                     374
# 4951                       0                    125                     108
# 3729                     596                   1000                     835
# 303                      456                  20000                     548
# 3900                       0                   1000                    1000
# 3117                       0                  26000                   11000
# 4313                      54                    985                     637
# 2971                     102                   2000                     973
# 794                        0                  26000                   21000
# 4927                      14                   2000                    1000
# 3480                     187                  14000                     900
# 395                      357                  23000                   14000
# 4226                     607                    813                     165
# 4565                      11                   1000                     891
# 2533                     168                   3000                     979
# 137                      282                  11000                   10000
# 4882                      45                   1000                     393
# 2771                      30                    941                     459
# 187                      386                  21000                   17000
# 656                      719                    605                     308
# 4631                       0                   3000                    1000
# 1220                   11000                    769                     698
# 1305                     118                  11000                    1000
# 2169                     118                    489                      93
#
#       Actor 3 Facebook Likes  Cast Total Facebook Likes  Movie Facebook Likes
# 4950                     405                       2364                   377
# 4408                       3                         18                   784
# 2562                     851                      18786                 18000
# 2798                     799                       3707                   896
# 4942                     697                       3700                     0
# 3452                     911                       5732                 18000
# 4769                     135                       1531                     0
# 2777                     418                      35501                     0
# 2292                     548                      24324                     0
# 389                       78                       1261                 41000
# 3345                     304                       1962                     0
# 2472                     720                       4142                     0
# 1449                     140                      41636                     0
# 204                       12                        699                     0
# 2619                     598                       4400                 12000
# 4182                     593                       3226                  3000
# 4282                     401                       1645                     0
# 590                      467                      16235                 21000
# 2493                     576                       6229                     0
# 4573                     842                       3931                     0
# 2568                     734                      15044                 31000
# 3915                     255                       2537                     0
# 4951                      56                        403                     0
# 3729                     697                       3300                     0
# 303                      394                      21393                 24000
# 3900                     904                       5203                   634
# 3117                    1000                      39175                 27000
# 4313                     455                       3065                   215
# 2971                     877                       5780                   701
# 794                    19000                      87697                123000
# 4927                     826                       4385                     0
# 3480                     887                      17104                   141
# 395                     4000                      45327                 14000
# 4226                     109                       1196                     0
# 4565                     121                       2323                     0
# 2533                      96                       4210                 15000
# 137                      103                      21175                 29000
# 4882                     224                       2166                   515
# 2771                     309                       2348                 17000
# 187                    12000                      59177                 65000
# 656                      217                       1441                     0
# 4631                     888                       5056                 23000
# 1220                     465                       2938                 35000
# 1305                     287                      12876                 11000
# 2169                      40                        679                     0
#
# [45 rows x 28 columns]

# %% [markdown]
# 44 películas duplicadas que hay que eliminar.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 6. Comprobar datos y abordar incoherencias

# %% [markdown]
# ## 7. Guardar DataSet

# %%
df.to_csv("../data/imdb_5000_movies_limpio.csv", index=False)
